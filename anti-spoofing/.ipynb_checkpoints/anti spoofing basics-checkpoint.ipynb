# %%
from glob import glob
import matplotlib.pyplot as plt
import pandas as pd
import os
import cv2
import numpy as np
import h5py
import keras
# Out:
# /Users/gagicha/anaconda/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
train_path='training_images/gunjan_real5.jpeg'
img=cv2.imread(train_path)
plt.imshow(img)
plt.show()
print(img.shape)
img=cv2.resize(img, (500,500), interpolation = cv2.INTER_AREA)
print(img.shape)
plt.imshow(img)
plt.show()
# print(img)

train_path='training_images/gunjan_fake5.jpeg'
img=cv2.imread(train_path)
plt.imshow(img)
plt.show()
print(img.shape)
img=cv2.resize(img, (500,500), interpolation = cv2.INTER_AREA)
print(img.shape)
plt.imshow(img)
plt.show()
# Out:
# (4608, 3456, 3)
# (500, 500, 3)
# (866, 646, 3)
# (500, 500, 3)

# %%
fig = plt.figure()

plt.subplot(2, 2, 1)
train_path='gunjan_real.jpeg'
img=cv2.imread(train_path)
plt.imshow(img)
plt.title('real')

plt.subplot(2, 2, 2)
train_path='gunjan_real.jpeg'
img=cv2.imread(train_path)
img=cv2.resize(img, (500,500), interpolation = cv2.INTER_LINEAR)
plt.imshow(img)
plt.title('real cropped')


plt.subplot(2, 2, 3)
train_path='gunjan_fake.jpeg'
img=cv2.imread(train_path)
plt.imshow(img)
plt.title('fake')


plt.subplot(2, 2, 4)
train_path='gunjan_fake.jpeg'
img=cv2.imread(train_path)
img=cv2.resize(img, (500,500), interpolation = cv2.INTER_LINEAR)
plt.imshow(img)
plt.title('fake cropped')

plt.show()
